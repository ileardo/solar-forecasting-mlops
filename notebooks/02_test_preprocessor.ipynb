# %%
from pathlib import Path

import pandas as pd
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.data.loader import (
    get_dataset_summary,
    load_generation_data,
    load_solar_data,
    load_weather_data,
    validate_data_integrity,
)

# %%
generation_df, weather_df = load_solar_data(Path('../data/raw'))
# Out:
# INFO:src.data.loader:Loaded generation data: 68778 rows, 7 columns
# /workspaces/solar-forecasting-mlops/src/data/loader.py:82: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["DATE_TIME"] = pd.to_datetime(df["DATE_TIME"])
# INFO:src.data.loader:Loaded weather data: 3182 rows, 6 columns

# %%
generation_df.head(3)
# Out:
#    DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 0 2020-05-15   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 1 2020-05-15   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 2 2020-05-15   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
#
#    TOTAL_YIELD
# 0    6259559.0
# 1    6183645.0
# 2    6987759.0

# %%
weather_df.head(3)
# Out:
#             DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0 2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 1 2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2 2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
#
#    MODULE_TEMPERATURE  IRRADIATION
# 0           22.857507          0.0
# 1           22.761668          0.0
# 2           22.592306          0.0

# %%
get_dataset_summary()
# Out:
# {'dataset_source': 'Kaggle - Solar Power Generation Data',
#  'focus': 'Plant 1 only',
#  'time_period': '34 days continuous data',
#  'frequency': 'Every 15 minutes',
#  'expected_shapes': {'generation': (68778, 7), 'weather': (3182, 6)},
#  'primary_target': 'AC_POWER (solar power generation in kW)',
#  'generation_columns': ['DATE_TIME',
#   'PLANT_ID',
#   'SOURCE_KEY',
#   'DC_POWER',
#   'AC_POWER',
#   'DAILY_YIELD',
#   'TOTAL_YIELD'],
#  'weather_columns': ['DATE_TIME',
#   'PLANT_ID',
#   'SOURCE_KEY',
#   'AMBIENT_TEMPERATURE',
#   'MODULE_TEMPERATURE',
#   'IRRADIATION']}

# %%
validate_data_integrity(generation_df, weather_df)
# Out:
# INFO:src.data.loader:Data validation completed. Found 2 issues.
# WARNING:src.data.loader:Data quality issue: Generation data contains multiple or incorrect plant IDs
# WARNING:src.data.loader:Data quality issue: Weather data contains multiple or incorrect plant IDs
# {'row_counts': {'generation': 68778, 'weather': 3182},
#  'date_ranges': {'generation': {'start': Timestamp('2020-05-15 00:00:00'),
#    'end': Timestamp('2020-06-17 23:45:00')},
#   'weather': {'start': Timestamp('2020-05-15 00:00:00'),
#    'end': Timestamp('2020-06-17 23:45:00')}},
#  'missing_values': {'generation': {'DATE_TIME': 0,
#    'PLANT_ID': 0,
#    'SOURCE_KEY': 0,
#    'DC_POWER': 0,
#    'AC_POWER': 0,
#    'DAILY_YIELD': 0,
#    'TOTAL_YIELD': 0},
#   'weather': {'DATE_TIME': 0,
#    'PLANT_ID': 0,
#    'SOURCE_KEY': 0,
#    'AMBIENT_TEMPERATURE': 0,
#    'MODULE_TEMPERATURE': 0,
#    'IRRADIATION': 0}},
#  'data_quality_issues': ['Generation data contains multiple or incorrect plant IDs',
#   'Weather data contains multiple or incorrect plant IDs']}

# %%
from src.data.preprocessor import SolarDataPreprocessor

# %%
preprocessor = SolarDataPreprocessor(target_frequency='1H', lag_hours=[24, 48, 72], scaling_method='standard')
# Out:
# INFO:src.data.preprocessor:Initialized SolarDataPreprocessor with frequency=1H

# %%
preprocessor.is_fitted
# Out:
# False

# %%
features_df, metadata = preprocessor.fit_transform(
    "../data/raw/Plant_1_Generation_Data.csv",
    "../data/raw/Plant_1_Weather_Sensor_Data.csv"
)
print(f"Features shape: {features_df.shape}")
# Out:
# INFO:src.data.preprocessor:Starting complete preprocessing pipeline...
# INFO:src.data.preprocessor:Loading generation and weather data...
# INFO:src.data.preprocessor:Successfully merged data: 68,774 records
# INFO:src.data.preprocessor:Creating temporal features...
# INFO:src.data.preprocessor:Temporal features created successfully
# INFO:src.data.preprocessor:Creating weather-derived features...
# INFO:src.data.preprocessor:Weather features created successfully
# INFO:src.data.preprocessor:Creating lag features...
# INFO:src.data.preprocessor:Lag features created successfully
# INFO:src.data.preprocessor:Resampling to 1H frequency...
# INFO:src.data.preprocessor:Resampled to 816 records
# INFO:src.data.preprocessor:Validating data quality...
# INFO:src.data.preprocessor:Data quality score: 1.000
# INFO:src.data.preprocessor:Preprocessing complete! Final shape: (796, 45)
# INFO:src.data.preprocessor:Total features: 44
# Features shape: (796, 45)

# %%
preprocessor.is_fitted
# Out:
# True

# %%
metadata
# Out:
# {'load_metadata': {'generation_records': 68778,
#   'weather_records': 3182,
#   'merged_records': 68774,
#   'date_range': {'start': Timestamp('2020-05-15 00:00:00'),
#    'end': Timestamp('2020-06-17 23:45:00')},
#   'merge_success_rate': 0.9999418418680392},
#  'quality_report': {'total_records': 816,
#   'missing_values': {'DATE_TIME': 0,
#    'AC_POWER': 20,
#    'DC_POWER': 20,
#    'DAILY_YIELD': 20,
#    'AMBIENT_TEMPERATURE': 20,
#    'MODULE_TEMPERATURE': 20,
#    'IRRADIATION': 20,
#    'hour': 20,
#    'day_of_year': 20,
#    'month': 20,
#    'weekday': 20,
#    'is_daylight': 20,
#    'solar_elevation_proxy': 20,
#    'hour_sin': 20,
#    'hour_cos': 20,
#    'day_sin': 20,
#    'day_cos': 20,
#    'season': 20,
#    'temp_difference': 20,
#    'temp_ratio': 20,
#    'irradiation_per_temp': 20,
#    'power_efficiency': 20,
#    'temp_irradiation_interaction': 20,
#    'temp_category': 20,
#    'irradiation_category': 347,
#    'ac_power_lag_24h': 20,
#    'irradiation_lag_24h': 20,
#    'ac_power_lag_48h': 20,
#    'irradiation_lag_48h': 20,
#    'ac_power_lag_72h': 20,
#    'irradiation_lag_72h': 20,
#    'ac_power_rolling_mean_6h': 20,
#    'ac_power_rolling_std_6h': 20,
#    'ac_power_rolling_mean_12h': 20,
#    'ac_power_rolling_std_12h': 20,
#    'ac_power_rolling_mean_24h': 20,
#    'ac_power_rolling_std_24h': 20,
#    'ac_power_same_hour_yesterday': 20},
#   'duplicate_timestamps': np.int64(0),
#   'negative_power': np.int64(0),
#   'zero_irradiation_with_power': np.int64(0),
#   'temperature_anomalies': {'extreme_ambient': np.int64(0),
#    'extreme_module': np.int64(0)},
#   'data_range': {'ac_power': {'min': np.float64(0.0),
#     'max': np.float64(1242.08630275)},
#    'irradiation': {'min': np.float64(0.0),
#     'max': np.float64(1.0117025772500001)},
#    'ambient_temp': {'min': np.float64(20.677156399999998),
#     'max': np.float64(34.989174409523805)}},
#   'quality_score': np.float64(1.0)},
#  'processing_steps': {'initial_merged_records': 68774,
#   'after_feature_engineering': 816,
#   'final_records_after_dropna': 796,
#   'rows_dropped_due_to_nan': 20},
#  'feature_counts': {'total_features': 44,
#   'temporal_features': 10,
#   'weather_features': 7,
#   'lag_features': 13,
#   'categorical_features': 0},
#  'feature_names': ['AC_POWER',
#   'DC_POWER',
#   'DAILY_YIELD',
#   'AMBIENT_TEMPERATURE',
#   'MODULE_TEMPERATURE',
#   'IRRADIATION',
#   'hour',
#   'day_of_year',
#   'month',
#   'weekday',
#   'is_daylight',
#   'solar_elevation_proxy',
#   'hour_sin',
#   'hour_cos',
#   'day_sin',
#   'day_cos',
#   'temp_difference',
#   'temp_ratio',
#   'irradiation_per_temp',
#   'power_efficiency',
#   'temp_irradiation_interaction',
#   'ac_power_lag_24h',
#   'irradiation_lag_24h',
#   'ac_power_lag_48h',
#   'irradiation_lag_48h',
#   'ac_power_lag_72h',
#   'irradiation_lag_72h',
#   'ac_power_rolling_mean_6h',
#   'ac_power_rolling_std_6h',
#   'ac_power_rolling_mean_12h',
#   'ac_power_rolling_std_12h',
#   'ac_power_rolling_mean_24h',
#   'ac_power_rolling_std_24h',
#   'ac_power_same_hour_yesterday',
#   'season_spring',
#   'season_summer',
#   'temp_category_cool',
#   'temp_category_optimal',
#   'temp_category_warm',
#   'temp_category_hot',
#   'irradiation_category_low',
#   'irradiation_category_medium',
#   'irradiation_category_high',
#   'irradiation_category_peak'],
#  'numeric_features': ['DC_POWER',
#   'DAILY_YIELD',
#   'AMBIENT_TEMPERATURE',
#   'MODULE_TEMPERATURE',
#   'IRRADIATION',
#   'hour',
#   'day_of_year',
#   'month',
#   'weekday',
#   'is_daylight',
#   'solar_elevation_proxy',
#   'hour_sin',
#   'hour_cos',
#   'day_sin',
#   'day_cos',
#   'temp_difference',
#   'temp_ratio',
#   'irradiation_per_temp',
#   'power_efficiency',
#   'temp_irradiation_interaction',
#   'ac_power_lag_24h',
#   'irradiation_lag_24h',
#   'ac_power_lag_48h',
#   'irradiation_lag_48h',
#   'ac_power_lag_72h',
#   'irradiation_lag_72h',
#   'ac_power_rolling_mean_6h',
#   'ac_power_rolling_std_6h',
#   'ac_power_rolling_mean_12h',
#   'ac_power_rolling_std_12h',
#   'ac_power_rolling_mean_24h',
#   'ac_power_rolling_std_24h',
#   'ac_power_same_hour_yesterday'],
#  'target_frequency': '1H',
#  'scaling_method': 'standard'}

# %%
features_df
# Out:
#               DATE_TIME  AC_POWER  DC_POWER  DAILY_YIELD  AMBIENT_TEMPERATURE  \
# 0   2020-05-15 00:00:00       0.0 -0.795368    -1.074052            -0.161791
# 1   2020-05-15 01:00:00       0.0 -0.795368    -1.074052            -0.264930
# 2   2020-05-15 02:00:00       0.0 -0.795368    -1.074052            -0.169556
# 3   2020-05-15 03:00:00       0.0 -0.795368    -1.074052            -0.179238
# 4   2020-05-15 04:00:00       0.0 -0.795368    -1.074052            -0.384172
# ..                  ...       ...       ...          ...                  ...
# 811 2020-06-17 19:00:00       0.0 -0.795368     0.843577            -0.655679
# 812 2020-06-17 20:00:00       0.0 -0.795368     0.806543            -0.790648
# 813 2020-06-17 21:00:00       0.0 -0.795368     0.806543            -0.771649
# 814 2020-06-17 22:00:00       0.0 -0.795368     0.768567            -0.984933
# 815 2020-06-17 23:00:00       0.0 -0.795368     0.780807            -1.065088
#
#      MODULE_TEMPERATURE  IRRADIATION      hour  day_of_year     month  ...  \
# 0             -0.704072     -0.78339 -1.694059    -1.702831 -1.025449  ...
# 1             -0.722684     -0.78339 -1.548372    -1.702831 -1.025449  ...
# 2             -0.632283     -0.78339 -1.402686    -1.702831 -1.025449  ...
# 3             -0.581528     -0.78339 -1.257000    -1.702831 -1.025449  ...
# 4             -0.746637     -0.78339 -1.111314    -1.702831 -1.025449  ...
# ..                  ...          ...       ...          ...       ...  ...
# 811           -0.722664     -0.78339  1.073978     1.659566  0.975182  ...
# 812           -0.837760     -0.78339  1.219664     1.659566  0.975182  ...
# 813           -0.779050     -0.78339  1.365350     1.659566  0.975182  ...
# 814           -0.834831     -0.78339  1.511036     1.659566  0.975182  ...
# 815           -0.855072     -0.78339  1.656722     1.659566  0.975182  ...
#
#      season_spring  season_summer  temp_category_cool  temp_category_optimal  \
# 0             True          False               False                   True
# 1             True          False               False                   True
# 2             True          False               False                   True
# 3             True          False               False                   True
# 4             True          False               False                   True
# ..             ...            ...                 ...                    ...
# 811          False           True               False                   True
# 812          False           True               False                   True
# 813          False           True               False                   True
# 814          False           True               False                   True
# 815          False           True               False                   True
#
#      temp_category_warm  temp_category_hot  irradiation_category_low  \
# 0                 False              False                     False
# 1                 False              False                     False
# 2                 False              False                     False
# 3                 False              False                     False
# 4                 False              False                     False
# ..                  ...                ...                       ...
# 811               False              False                     False
# 812               False              False                     False
# 813               False              False                     False
# 814               False              False                     False
# 815               False              False                     False
#
#      irradiation_category_medium  irradiation_category_high  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ..                           ...                        ...
# 811                        False                      False
# 812                        False                      False
# 813                        False                      False
# 814                        False                      False
# 815                        False                      False
#
#      irradiation_category_peak
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 811                      False
# 812                      False
# 813                      False
# 814                      False
# 815                      False
#
# [796 rows x 45 columns]

# %%
preprocessor.save_preprocessor('preprocessor.pkl')
# Out:
# INFO:src.data.preprocessor:Preprocessor saved to: preprocessor.pkl

# %%
loaded_preprocessor = SolarDataPreprocessor.load_preprocessor('preprocessor.pkl')
# Out:
# INFO:src.data.preprocessor:Preprocessor loaded from: preprocessor.pkl

# %%
loaded_preprocessor.is_fitted
# Out:
# True
